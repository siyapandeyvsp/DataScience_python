# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# - loading data
# - selection
#    - cols
#    - rows
# - manipulation
#    - add columns
#    - remove columns
#    - rename columns
#    - change data types
#    - delete data
#    - remove duplicaties
#    - sort
#    - group
#    - pivot
#    - merge
# - visualize
#    - in line plot
#    - bar plot
#    - histogram
#    - box plot
#    - scatter plus
#    - pie charge
#    - heatmap
#    - world cloud

# %%
penguins=sns.load_dataset('penguins')
penguins

# %% [markdown]
# - analysis
#   - univariate analysis
#   - bi-variate analysis
#   - multi-variate analysis

# %% [markdown]
# - loading data
#   - custom data from a variable
#   - excel data
#   - csv/json etc
#   - database(sql)

# %%
students={
    'name':['Vaibhav', 'Siya', ' Aman','Amjad','Sneha','Aditi','Bhupendra'],
    'college':['SRMCEM','SRMCEM','KMC','KMC','CU','SRMCEM','SRMCEM'],
    'dob':['25 Jan', '2 Feb','2 Apr', '16Aug','16Sep','17  Dec','22 May']
}

sdf=pd.DataFrame(students)

# %% [markdown]
# loaded data is called dataframe
# can perform manipulations on data frame

# %%
data= pd.read_excel('C:/Users/dell/Desktop/personal_work/digipodium/sample.xlsx')
data

# %%
data.info()

# %% [markdown]
# non numerical data in pandas in called Object(texual or ctegorical)

# %%
data.columns.tolist()

# %%
data['Item'] #column selection as a dictionary key

# %%
data.amt # column selection as object attribute

# %% [markdown]
# select 2 columns
#
# ```
# data[collist]
# ```

# %%
data[['Item','amt']]

# %% [markdown]
# operations between columns

# %%
data['amt'] *data['qty']

# %% [markdown]
# adding columns
#
# ```
# data['new_col]=expression
# ```

# %%
data['total']=data['amt']*data['qty']
data

# %%
data['crap']='some crap'
data

# %% [markdown]
# removing columns

# %%
data.drop(columns=['crap'],inplace=True) #inplace=True makes changes permanent in dataframe 
data

# %% [markdown]
# Select rows
#
# data[0] searches by column by default
# use data.iloc[0] istead

# %%
data.iloc[0]

# %%
data.iloc[:2]

# %%
data.drop(index=[2]) #no real changes , only visible to us not in db

# %%
data

# %%
sdf

# %%
sdf.drop(index=[2,3], inplace=True)

# %%
sdf.drop(index=[0,6])

# %%
sdf

# %%
data['qty']=data['qty']-10

# %%
data

# %% [markdown]
# Rename column name

# %%
data.columns.tolist()

# %% [markdown]
# This is called :
# data preprocessing/
# data wrangling /
# data cleaning

# %%
data.rename(
    mapper={'Item':'Product',
            'qty':'Quantity',
            'amt':'Price',
            'total':'Expenditure'},
    axis=1,
    inplace=True
)
data

#mapper takes dictionary values as {'Old Value':'New Value'} and exchanges them

# %% [markdown]
# 23-OCT-23
# Operations
# - delete data
#   - columns
#   - indexes
#
# - remove duplicates
# - sort
# - group
# - pivot
# - merge

# %%
penguins.drop? #?tells the signature

# %%
penguins.drop(columns='body_mass_g') #not work in place

# %%
penguins.drop(columns=['island','body_mass_g']) #to drop columns

# %%
penguins.drop(index=2)#drop row by 3rd index

# %%
penguins.drop(index=[0,1,2,3,4])

# %%
penguins.drop(index=range(10))

# %% [markdown]
# - sometimes there are missing values its called Not a Number NaN
# - wherever there exist nan in an int column its convert to float
# - if textual data is missing it becomes object

# %%
np.nan

# %% [markdown]
# find the number of missing values in each column

# %%
penguins.isnull().sum()

# %%
sns.heatmap(penguins.isnull(),cbar=False,) #overall null value visualization

# %%
penguins.isnull().sum().plot(kind='bar') #columnwise null value visualization

# %% [markdown]
# removing missing values(non values)

# %%
penguins.dropna()#drop rows with null values

# %% [markdown]
# how to see number of records?

# %%
penguins.dropna().shape

# %%
penguins.shape

# %%
penguins.dropna(inplace=True)
print(penguins.shape)

# %% [markdown]
# Remove duplicate values

# %%
penguins.drop_duplicates()

# %%
penguins.drop_duplicates(subset=['species'])

# %%
penguins.drop_duplicates(subset=['bill_length_mm'])

# %% [markdown]
# Sorting
#  - by default we have quick sort implemented due to small time complexity

# %%
penguins.sort_values(by='sex', ascending=False)

# %%
penguins.sort_values(by=['sex','island'])

# %%
penguins.sort_values(by=['bill_length_mm','body_mass_g','island'],ascending=False)

# %%
penguins.sort_index(ascending=False)

# %% [markdown]
# axis=0=row
# axis=1=column

# %%
penguins.sort_index?

# %% [markdown]
# Datatypes in pandas
#  - int
#  - float
#  - boolean
#  - datetime
#  - object(if datatype is not understood by pandas then object is used)
#  - string(not understood by pandas , unless you specify)
#  - category

# %%
penguins.info()

# %%
penguins.dtypes #data types of columns

# %%
penguins.select_dtypes(include='number')

# %%
penguins.select_dtypes(include='object')

# %%
penguins.select_dtypes(exclude='number')#select all columns except numeric

# %% [markdown]
# change the data typesof a columns

# %%
penguins['island'].astype('category') #not actuall applied on the column

# %%
penguins.dtype

# %%
penguins.sex=penguins.sex.astype('bool')
penguins.head()

# %% [markdown]
# Simple visualization- univariate
# - for numerical data
#   - line plot -> .`plot()`
#   - histogram -> `.hist()`
#   - bar plot -> `.plot(kind=bar)`
#   - area plot -> `.plot(kind=area)`

# %%
penguins['bill_depth_mm'].hist()

# %%
penguins['bill_depth_mm'].plot(figsize=(15,5))

# %%
penguins['bill_depth_mm'].plot(kind='area',figsize=(15,5))

# %%
penguins['bill_depth_mm'].plot(kind='box',figsize=(15,5))

# %%
penguins.columns

# %%
penguins['bill_depth_mm'].plot(kind='box',figsize=(5,3), vert=False)

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %% [markdown]
# Comparing univariate data in a single graph

# %%
penguins[['bill_depth_mm','bill_length_mm']]

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot()

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(kind='box',figsize=(15,5))

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist(bins=5,figsize=(15,5))

# %% [markdown]
# putting columns visualizations in subplots

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout=(1,2),subplots=True,figsize=(15,5))

# %%
sns.displot(data=penguins,x='bill_depth_mm')

# %%
sns.displot(data=penguins,x='bill_depth_mm', hue='island')

# %%
sns.displot(data=penguins,x='body_mass_g', hue='island')

# %%
sns.countplot(data=penguins,x='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(data=penguins,x='island',hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# Bivariate analysis
#  - scatter plot
#  - violin plot(alternative to box plot)
#  - pair plot

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='flipper_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='body_mass_g')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# CHange colors of map

# %%
sns.color_palette()
#set color for all graphs
#RdBu
#rainbow
#virlis
#cool
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# cmap=color sequence

# %%
sns.set_palette('rainbow')

# %%
sns.scatterplot(data=penguins , x='bill_length_mm', y='bill_depth_mm', hue='island',palette='hot')
#color for specific graph
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# # Seaborn Relational Tutorial
# - https://seaborn.pydata.org/tutorial/relational.html
#
# - Scatter plot : used for seeing relation bw 2 vars
# - hue used to give colors with a categorical variable

# %%
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="smoker", palette=('RdBu')
)

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
)

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip",
    hue="size", palette="ch:r=-.5,l=.75"
)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", size="size")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", size="size", style='size')

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(150, 200),style='size'
)

# %% [markdown]
# # Line Plot
# - Scatter is used to display values but if we want to see change in value of variable with respect to a function or time , we use line plot

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %%
dowjones.columns
# Out:
# Index(['Date', 'Price'], dtype='object')

# %% [markdown]
# # Aggregation and representing uncertainty
# - multiple measurements for the same value of the x variable. The default behavior in seaborn is to aggregate the multiple measurements at each x value by plotting the mean and the 95% confidence interval around the mean:

# %% [markdown]
# - prediction
# - relplot and regplot
# - kis range tk values jaa skti h
# - shows the corelations

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %% [markdown]
# - confidence means some algo is being used

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None,
)

# %% [markdown]
# Another good option, especially with larger data, is to represent the spread of the distribution at each timepoint by plotting the standard deviation instead of a confidence interval:

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar="sd",
)

# %% [markdown]
# To turn off aggregation altogether, set the estimator parameter to None This might produce a strange effect when the data have multiple observations at each point.

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    estimator=None,
)

# %% [markdown]
# # Plotting subsets of data with semantic mappings

# %% [markdown]
# Using semantics in lineplot() will also determine how the data get aggregated. For example, adding a hue semantic with two levels splits the plot into two lines and error bands, coloring each to indicate which subset of the data they correspond to.

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event",
)

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %% [markdown]
# apply line style

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    hue="region", style="event",
)

# %% [markdown]
# apply markers

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="region", style="event",
    dashes=False, markers=True,
)

# %% [markdown]
# When you are working with repeated measures data (that is, you have units that were sampled multiple times), you can also plot each sampling unit separately without distinguishing them through semantics. This avoids cluttering the legend:

# %%
sns.relplot(
    data=fmri.query("event == 'stim'"), kind="line",
    x="timepoint", y="signal", hue="region",
    units="subject", estimator=None,
)

# %%
#grouping 
#merging
#pivot
